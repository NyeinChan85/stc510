# %%
#importing pandas, matplotlib.pyplot and networkx libraries
import pandas as pd 
import matplotlib.pyplot as plt
import networkx as nx

# %%
#creating a dataframe using the csv which contains Cocaine Trafficking Organization in New York (source: http://www.casos.cs.cmu.edu/tools/datasets/external/index.php#covert)
df = pd.read_csv('COCAINE_DEALING.csv', index_col=0)
df.head()
# Out:
#          Bill  Blacky  Bruce  Charles  Dante  David  Donald  Doug  Fabio  \
# Bill        0       0      0        0      0      0       0     0      0
# Blacky      0       0      0        0      1      0       0     0      0
# Bruce       0       0      0        0      0      0       0     0      0
# Charles     0       0      0        0      0      0       0     0      0
# Dante       0       0      0        0      0      0       0     0      0
#
#          Frank  ...  Marzio  Menna  Peretta  Peter  Robert  Rosa  Ross  Shawn  \
# Bill         0  ...       0      0        0      0       0     0     0      0
# Blacky       1  ...       0      0        0      0       0     0     1      0
# Bruce        0  ...       0      0        0      0       0     0     0      0
# Charles      0  ...       0      0        0      0       0     0     0      0
# Dante        0  ...       0      0        0      0       1     0     0      0
#
#          Steve  Tommy
# Bill         0      0
# ...

# %%
#priting the number of rows and colomns that the df contains
print(df.shape)
# Out:
# (28, 28)

# %%
#summary of our dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28 entries, Bill to Tommy
# Data columns (total 28 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Bill     28 non-null     int64
#  1   Blacky   28 non-null     int64
#  2   Bruce    28 non-null     int64
#  3   Charles  28 non-null     int64
#  4   Dante    28 non-null     int64
#  5   David    28 non-null     int64
#  6   Donald   28 non-null     int64
#  7   Doug     28 non-null     int64
#  8   Fabio    28 non-null     int64
#  9   Frank    28 non-null     int64
#  10  Gabriel  28 non-null     int64
#  11  Howard   28 non-null     int64
#  12  Jenny    28 non-null     int64
#  13  Kay      28 non-null     int64
#  14  Lara     28 non-null     int64
#  15  Lorena   28 non-null     int64
#  16  Louis    28 non-null     int64
#  17  Marky    28 non-null     int64
#  18  Marzio   28 non-null     int64
#  19  Menna    28 non-null     int64
#  20  Peretta  28 non-null     int64
# ...

# %%
#creating a graph G using the dataframe: df
G = nx.Graph(df)

# %%
print(G)
# Out:
# Graph with 28 nodes and 40 edges

# %%
#computing the betweenness centrality for each node
nx.betweenness_centrality(G)
# Out:
# {'Bill': 0.0,
#  'Blacky': 0.011396011396011397,
#  'Bruce': 0.0,
#  'Charles': 0.0,
#  'Dante': 0.07407407407407408,
#  'David': 0.0,
#  'Donald': 0.0,
#  'Doug': 0.0,
#  'Fabio': 0.005698005698005698,
#  'Frank': 0.0,
#  'Gabriel': 0.0,
#  'Howard': 0.0,
#  'Jenny': 0.0,
#  'Kay': 0.8874643874643875,
#  'Lara': 0.0,
#  'Lorena': 0.0,
#  'Louis': 0.0,
#  'Marky': 0.0,
#  'Marzio': 0.0,
#  'Menna': 0.011396011396011397,
#  'Peretta': 0.0,
#  'Peter': 0.0,
#  'Robert': 0.0,
#  'Rosa': 0.0,
#  'Ross': 0.0,
#  'Shawn': 0.0,
#  'Steve': 0.0754985754985755,
#  'Tommy': 0.08831908831908833}

# %%
#calculating the eigenvector centrality for each node
nx.eigenvector_centrality(G)
# Out:
# {'Bill': 0.10914784648235058,
#  'Blacky': 0.24208528352095485,
#  'Bruce': 0.10914784648235058,
#  'Charles': 0.10914784648235058,
#  'Dante': 0.15596890382984238,
#  'David': 0.15741875858791812,
#  'Donald': 0.15741875858791812,
#  'Doug': 0.10914784648235058,
#  'Fabio': 0.18716389059462682,
#  'Frank': 0.19656998544745258,
#  'Gabriel': 0.10914784648235058,
#  'Howard': 0.10914784648235058,
#  'Jenny': 0.10914784648235058,
#  'Kay': 0.6275743358704476,
#  'Lara': 0.10914784648235058,
#  'Lorena': 0.10914784648235058,
#  'Louis': 0.10914784648235058,
#  'Marky': 0.10914784648235058,
#  'Marzio': 0.15741875858791812,
#  'Menna': 0.2605739987191541,
#  'Peretta': 0.15446667561354432,
#  'Peter': 0.1388929784890593,
#  'Robert': 0.027125925474548625,
#  'Rosa': 0.04827091210556753,
#  'Ross': 0.15125115631625888,
#  'Shawn': 0.02974513200670873,
#  'Steve': 0.1710285809149624,
#  'Tommy': 0.2775475379112082}

# %%
#calculating the average clustering coefficient
nx.average_clustering(G)
# Out:
# 0.3435189293108548

# %%
#calculating centrality measures for nodes 
nx.degree_centrality(G)
# Out:
# {'Bill': 0.037037037037037035,
#  'Blacky': 0.18518518518518517,
#  'Bruce': 0.037037037037037035,
#  'Charles': 0.037037037037037035,
#  'Dante': 0.1111111111111111,
#  'David': 0.07407407407407407,
#  'Donald': 0.07407407407407407,
#  'Doug': 0.037037037037037035,
#  'Fabio': 0.1111111111111111,
#  'Frank': 0.1111111111111111,
#  'Gabriel': 0.037037037037037035,
#  'Howard': 0.037037037037037035,
#  'Jenny': 0.037037037037037035,
#  'Kay': 0.8888888888888888,
#  'Lara': 0.037037037037037035,
#  'Lorena': 0.037037037037037035,
#  'Louis': 0.037037037037037035,
#  'Marky': 0.037037037037037035,
#  'Marzio': 0.07407407407407407,
#  'Menna': 0.18518518518518517,
#  'Peretta': 0.07407407407407407,
#  'Peter': 0.07407407407407407,
#  'Robert': 0.037037037037037035,
#  'Rosa': 0.037037037037037035,
#  'Ross': 0.07407407407407407,
#  'Shawn': 0.037037037037037035,
#  'Steve': 0.14814814814814814,
#  'Tommy': 0.25925925925925924}

# %%
#computing positions for notes using the spring layout 
nx.spring_layout(G)
# Out:
# {'Bill': array([-0.39142428, -0.34367203]),
#  'Blacky': array([ 0.10324056, -0.09938503]),
#  'Bruce': array([-0.44919248,  0.58384165]),
#  'Charles': array([-0.36021403, -0.15079093]),
#  'Dante': array([-0.17637241, -0.04288685]),
#  'David': array([ 0.05371309, -0.28072661]),
#  'Donald': array([-0.44089981,  0.00390694]),
#  'Doug': array([-0.18469541,  0.37432354]),
#  'Fabio': array([-0.13527501,  0.14564129]),
#  'Frank': array([ 0.23148569, -0.05138799]),
#  'Gabriel': array([-0.44734328,  0.26318697]),
#  'Howard': array([ 0.59905405, -0.45371637]),
#  'Jenny': array([0.74883085, 0.16671257]),
#  'Kay': array([0.02175749, 0.00552741]),
#  'Lara': array([ 0.53256842, -0.08991425]),
#  'Lorena': array([0.4666864 , 0.24839962]),
#  'Louis': array([ 0.30361603, -0.31626307]),
#  'Marky': array([ 0.02436562, -0.67860326]),
#  'Marzio': array([-0.26533839, -0.54845151]),
#  'Menna': array([0.0927615 , 0.11659456]),
#  'Peretta': array([0.36114223, 0.48295429]),
# ...

# %%
#visualizing the newtwork
nx.draw_networkx(G)

# %%
# the loop will iterate throgh each individual row of df, and for each row, it will iterates all the columns
for source, row in df.iterrows():
    for target, weight in row.iteritems():
        # checking whether there is a connection between the source and target nodes.
        if weight != 0:
            #adding egdes to the graph
            G.add_edge(source, target, weight=weight)

# %%
#finding out degree centrality and printing it
degree_centrality = nx.degree_centrality(G)

# %%
print(degree_centrality)
# Out:
# {'Blacky': 0.18518518518518517, 'Dante': 0.1111111111111111, 'Frank': 0.1111111111111111, 'Ross': 0.07407407407407407, 'Robert': 0.037037037037037035, 'Kay': 0.8888888888888888, 'Bill': 0.037037037037037035, 'Bruce': 0.037037037037037035, 'Charles': 0.037037037037037035, 'David': 0.07407407407407407, 'Donald': 0.07407407407407407, 'Doug': 0.037037037037037035, 'Fabio': 0.1111111111111111, 'Gabriel': 0.037037037037037035, 'Howard': 0.037037037037037035, 'Jenny': 0.037037037037037035, 'Lara': 0.037037037037037035, 'Lorena': 0.037037037037037035, 'Louis': 0.037037037037037035, 'Marky': 0.037037037037037035, 'Marzio': 0.07407407407407407, 'Menna': 0.18518518518518517, 'Peretta': 0.07407407407407407, 'Peter': 0.07407407407407407, 'Steve': 0.14814814814814814, 'Tommy': 0.25925925925925924, 'Shawn': 0.037037037037037035, 'Rosa': 0.037037037037037035}

# %%
#assigning the node with minimum centrality as the the weakest list 
weakest_link = min(degree_centrality, key=degree_centrality.get)

#analyzing the graph and visualizing the network
plt.figure(figsize=(13, 10))
pos = nx.spring_layout(G, seed=45)  

nx.draw_networkx(G, pos, node_size=200, width=0.5, font_size=10)

#determing the wealkest link and drawing it
nx.draw_networkx_nodes(G, pos, nodelist=[weakest_link], node_color='y', node_size=200)

#adding title to the plot and displaying the graph
plt.title('Covert Social Network - Cocaine Trafficking Organization in New York ')
plt.text(0.5, 0.95, '(the weakest link is highlighted in yellow)', horizontalalignment='center', fontsize=10, transform=plt.gca().transAxes)
plt.axis('off')
plt.show()

#creating a graph which is a copy of original graph
G_excluding_weakest_link = G.copy()

#removing the weakest link from the newly created graph
G_excluding_weakest_link.remove_node(weakest_link)

plt.figure(figsize=(13, 10))
pos_excluding_weakest_link = nx.spring_layout(G_excluding_weakest_link, seed=40)

nx.draw_networkx(G_excluding_weakest_link, pos_excluding_weakest_link, node_size=200, width=0.5, font_size=10)

#adding title to the plot and displaying the graph
plt.title('Covert Social Network - Cocaine Trafficking Organization in New York')
plt.text(0.5, 0.95, '(after the weakest link was removed)', horizontalalignment='center', fontsize=10, transform=plt.gca().transAxes)
plt.axis('off')
plt.show()

# %%
print(G_excluding_weakest_link)
# Out:
# Graph with 27 nodes and 39 edges

# %%
nx.average_clustering(G_excluding_weakest_link)
# Out:
# 0.38093321064335556

# %%
#nx.draw_networkx(G_excluding_weakest_link)

# %%
nx.betweenness_centrality(G_excluding_weakest_link)
# Out:
# {'Bill': 0.0,
#  'Blacky': 0.007692307692307693,
#  'Bruce': 0.0,
#  'Charles': 0.0,
#  'Dante': 0.0,
#  'David': 0.0,
#  'Donald': 0.0,
#  'Doug': 0.0,
#  'Fabio': 0.006153846153846154,
#  'Frank': 0.0,
#  'Gabriel': 0.0,
#  'Howard': 0.0,
#  'Jenny': 0.0,
#  'Kay': 0.8892307692307693,
#  'Lara': 0.0,
#  'Lorena': 0.0,
#  'Louis': 0.0,
#  'Marky': 0.0,
#  'Marzio': 0.0,
#  'Menna': 0.012307692307692308,
#  'Peretta': 0.0,
#  'Peter': 0.0,
#  'Rosa': 0.0,
#  'Ross': 0.0,
#  'Shawn': 0.0,
#  'Steve': 0.07846153846153846,
#  'Tommy': 0.09230769230769231}

# %%
nx.spring_layout(G_excluding_weakest_link)
# Out:
# {'Bill': array([ 0.1749409 , -0.45259831]),
#  'Blacky': array([-0.07823619,  0.22697944]),
#  'Bruce': array([-0.69738305,  0.39020164]),
#  'Charles': array([ 0.28201652, -0.23256896]),
#  'Dante': array([-0.15421303,  0.15221403]),
#  'David': array([0.12409151, 0.252232  ]),
#  'Donald': array([ 0.41624048, -0.09413471]),
#  'Doug': array([-0.43572537, -0.14557706]),
#  'Fabio': array([-0.15570933, -0.25273329]),
#  'Frank': array([-0.26768383,  0.03020283]),
#  'Gabriel': array([0.47511208, 0.14280181]),
#  'Howard': array([ 0.66062651, -0.28731035]),
#  'Jenny': array([0.71204486, 0.29767239]),
#  'Kay': array([-0.03028367,  0.0460921 ]),
#  'Lara': array([-0.08655063,  0.57994342]),
#  'Lorena': array([0.17462249, 0.56688801]),
#  'Louis': array([-0.34580473,  0.34879365]),
#  'Marky': array([-0.34198853,  0.73864715]),
#  'Marzio': array([0.40910545, 0.33316529]),
#  'Menna': array([-0.16217122,  0.00711193]),
#  'Peretta': array([-0.64653015,  0.00396192]),
# ...

# %% [markdown]
# CONCLUSION
# --------------------
# Removing the weakest link in a covert social network has significant consequences. Firstly, it is noticeable that the nx.average_clustering coefficient has increased, indicating how the remaining nodes are well-connected after the weakest link was removed. Secondly, it divides the network into separate parts, cutting off nodes connected through the weakest link. This reduction in connectivity limits access to critical information for nodes reliant on the weakest link.
#
# Without the weakest link, the network's structure changes, with some nodes gaining importance while others become less significant. Essentially, removing the weakest link alters communication, collaboration, and network structure, offering insights into resilience and vulnerabilities.
